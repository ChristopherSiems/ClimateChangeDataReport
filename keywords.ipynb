# %%
from nltk.stem import PorterStemmer
import json

# %%
words = [
  "Solar",
  "Wind",
  "Hydro",
  "Biomass",
  "Geothermal",
  "Tidal",
  "Renewable",
  "Clean",
  "Sustainable",
  "Efficient",
  "Green",
  "Photovoltaic",
  "Carbon-neutral",
  "Biofuel",
  "Electric",
  "Hydropower",
  "Wave",
  "Off-grid",
  "Grid-connected",
  "Fission",
  "Fusion",
  "Thorium",
  "Low-carbon",
  "Reactor",
  "Waste-management",
  "Advanced-reactor",
  "Cogeneration",
  "Microgrid",
  "Smart-grid",
  "Net-zero",
  "Modular",
  "Storage",
  "Battery",
  "Inverter",
  "Converter",
  "Interconnection",
  "Microturbine",
  "Fuel-cell",
  "Demand-side",
  "Energy-storage",
  "Energy-efficiency",
  "Carbon-trading",
  "Emissions",
  "Carbon-footprint",
  "Offset",
  "Cap-and-trade",
  "Carbon-capture",
  "Sequestration",
  "Renewable-energy-certificates",
  "Green-building",
  "LEED",
  "Sustainability",
  "Environmental",
  "Ecological",
  "Efficiency",
  "Renewables",
  "Microgeneration",
  "Grid-parity",
  "Electric-vehicle",
  "Eco-friendly",
  "Climate-neutral",
  "Windfarm",
  "Hydropower-plant",
  "Solar-panel",
  "Energy-audit",
  "Carbon-footprint",
  "Carbon-neutral",
  "Clean-energy",
  "Greenhouse-gas",
  "Carbon-emission",
  "Emission-reduction",
  "Energy-efficient",
  "Energy-star",
  "Sustainability",
  "Zero-emission",
  "Smart-meter",
  "Carbon-offset",
  "Carbon-capture",
  "Climate-change",
  "Environmental",
  "Pollution",
  "Renewable-fuel",
  "Hybrid-vehicle",
  "Bio-energy",
  "Bio-mass",
  "Renewable-resource",
  "Hydro-turbine",
  "Wind-turbine",
  "Solar-farm",
  "Eco-conscious",
  "Eco-friendly",
  "Sustainability",
  "Carbon-footprint",
  "Climate-action",
  "Eco-activism",
  "Green-living",
  "Eco-system",
  "Eco-friendly",
  "Green-energy",
  "Greenhouse-effect",
  "Net-zero",
  "Renewable-energy",
  "Energy-conservation",
  "Carbon-footprint",
  "Clean-energy",
  "Eco-friendly",
  "Emissions",
  "Environmental",
  "Renewable",
  "Sustainable",
  'climate'
]

# %%
stemmer = PorterStemmer()

keywords = []
for term in words:
  keywords.append(stemmer.stem(term.lower()))
keywords = list(set(keywords))
keywords
# Out:
# ['wind',
#  'off-grid',
#  'eco-activ',
#  'tidal',
#  'wind-turbin',
#  'climate-chang',
#  'solar-farm',
#  'grid-par',
#  'renewable-resourc',
#  'energy-effici',
#  'energy-audit',
#  'green',
#  'bio-mass',
#  'biofuel',
#  'leed',
#  'emission-reduct',
#  'hydropower-pl',
#  'solar-panel',
#  'carbon-trad',
#  'sequestr',
#  'invert',
#  'microgener',
#  'windfarm',
#  'biomass',
#  'microgrid',
#  'effici',
#  'wave',
#  'fusion',
#  'bio-energi',
#  'convert',
#  'interconnect',
#  'advanced-reactor',
#  'renew',
#  'hydro',
#  'greenhouse-effect',
#  'cap-and-trad',
#  'net-zero',
#  'demand-sid',
#  'waste-manag',
#  'climate-neutr',
#  'microturbin',
#  'reactor',
#  'electric-vehicl',
#  'hydropow',
#  'sustain',
#  'offset',
#  'renewable-fuel',
#  'green-liv',
#  'zero-emiss',
#  'eco-consci',
#  'thorium',
#  'hydro-turbin',
#  'smart-grid',
#  'greenhouse-ga',
#  'carbon-emiss',
#  'carbon-offset',
#  'fission',
#  'cogener',
#  'pollut',
#  'renewable-energy-certif',
#  'climate-act',
#  'emiss',
#  'modular',
#  'renewable-energi',
#  'storag',
#  'environment',
#  'batteri',
#  'eco-friendli',
#  'ecolog',
#  'geotherm',
#  'green-build',
#  'climat',
#  'fuel-cel',
#  'eco-system',
#  'energy-conserv',
#  'green-energi',
#  'carbon-neutr',
#  'photovolta',
#  'grid-connect',
#  'energy-star',
#  'hybrid-vehicl',
#  'clean',
#  'energy-storag',
#  'clean-energi',
#  'electr',
#  'carbon-footprint',
#  'smart-met',
#  'carbon-captur',
#  'solar',
#  'low-carbon']

# %%
with open('lists/keywords.json', 'w') as file:
  json.dump(keywords, file)
